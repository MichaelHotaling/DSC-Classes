# %% [markdown]
# Assignment: ASSIGNMENT 3
# <br>Name: Hotaling, Michael
# <br>Date: 2020-09-07

# %% [markdown]
# Load the ggplot2 package

# %%
library(ggplot2)
theme_set(theme_minimal())
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 3.6.3"

# %% [markdown]
# Set the working directory to the root of your DSC 520 directory.

# %%
setwd("..")
setwd("..")
getwd()
# Out:
# [1] "C:/Users/MHotaling144186/Documents/dsc520"

# %% [markdown]
# Load the `data/r4ds/heights.csv` to `heights_df`

# %%
heights_df <- read.csv("data/r4ds/heights.csv")

# %% [markdown]
#  https://ggplot2.tidyverse.org/reference/geom_point.html
# <br>Using `geom_point()` create three scatterplots for
# <br>`height` vs. `earn`

# %%
ggplot(heights_df, aes(x=height, y=earn)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# `age` vs. `earn`

# %%
ggplot(heights_df, aes(x=age, y=earn)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# `ed` vs. `earn`

# %%
ggplot(heights_df, aes(x=ed, y=earn)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# Re-create the three scatterplots and add a regression trend line using
# <br>the `geom_smooth()` function
# <br>`height` vs. `earn`

# %%
ggplot(heights_df, aes(x=height, y=earn)) + geom_point() + geom_smooth()
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %% [markdown]
# `age` vs. `earn`

# %%
ggplot(heights_df, aes(x=age, y=earn)) + geom_point() + geom_smooth()
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %% [markdown]
# `ed` vs. `earn`

# %%
ggplot(heights_df, aes(x=ed, y=earn)) + geom_point() + geom_smooth()
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %% [markdown]
# Create a scatterplot of `height` vs. `earn`.  <br>Use `sex` as the `col` (color) attribute

# %%
ggplot(heights_df, aes(x=height, y=earn, color=sex)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# Using `ggtitle()`, `xlab()`, and `ylab()` to add a title, x label, and y label to the previous plot
# <br>Title: Height vs. Earnings
# <br>X label: Height (Inches)
# <br>Y Label: Earnings (Dollars)

# %%
ggplot(heights_df, aes(x=height, y=earn, col=sex)) + geom_point() + ggtitle("Height vs. Earnings") + xlab("Height (Inches)") + ylab("Earnings (Dollars)")
# Out:
# plot without title

# %% [markdown]
# https://ggplot2.tidyverse.org/reference/geom_histogram.html
# <br>Create a histogram of the `earn` variable using `geom_histogram()`

# %%
ggplot(heights_df, aes(earn)) + geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# Create a histogram of the `earn` variable using `geom_histogram()`
# Use 10 bins

# %%
ggplot(heights_df, aes(earn)) + geom_histogram(bins = 10)
# Out:
# plot without title

# %% [markdown]
# https://ggplot2.tidyverse.org/reference/geom_density.html
# Create a kernel density plot of `earn` using `geom_density()`

# %%
ggplot(heights_df, aes(earn)) +  geom_density()
# Out:
# plot without title
