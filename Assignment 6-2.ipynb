# %% [markdown]
# DSC550<br>
# 1/21/2021<br>
# Michael Hotaling

# %% [markdown]
# # 6.2 Exercise:<Br> Titanic Tutorial <br>Part 1: Graphics Analysis

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Step 1:  Load the data from the “train.csv” file into a DataFrame.

# %%
data = pd.read_csv("train.csv")

# %% [markdown]
# ### Step 2:	Display the dimensions of the file (so you’ll have a good idea the amount of data you are working with.)

# %%
print("There are {} rows and {} columns in this dataframe".format(data.shape[0], data.shape[1]))
# Out:
# There are 891 rows and 12 columns in this dataframe

# %% [markdown]
# ###  Step 3: Display the first 5 rows of data so you can see the column headings and the type of data for each column.

# %% [markdown]
# - Notice that Survived is represented as a 1 or 0
# - Notice that missing data is represented as “NaN”
# - The Survived variable will be the “target” and the other variables will be the “features”

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Step 4:	Think about some questions that might help you predict who will survive:
# - What do the variables look like? For example, are they numerical or categorical data. If they are numerical, what are their distribution; if they are categorical, how many are they in different categories?
#
# | Variable    | Definition                                      | Key                                                                                |
# |-------------|-------------------------------------------------|------------------------------------------------------------------------------------|
# | PassengerID |                                                 |                                                                                    |
# | Survived    | Survival                                        | 0 = No, 1 = Yes                                                                    |
# | Pclass      | Ticket class                                    | 1 = 1st Class, 2 = 2nd Class, 3 = 3rd Class                                        |
# | Name        | Name of the Passenger                           |                                                                                    |
# | Sex         | Sex                                             |                                                                                    |
# | Age         | Age in Years                                    | Age is a fractional if less than 1. If age is estimated, it is in the form of xx.5 |
# | SibSp       | Number of siblings / spouses aboard the Titanic | brother, sister, stepbrother, stepsister, husband, wife                            |
# | Parch       | Number of parents / children aboard the Titanic | mother, father, daughter, son, stepdaughter, stepson                               |
# | Ticket      | Ticket Number                                   |                                                                                    |
# | Fare        | Passenger Fare                                  |                                                                                    |
# | Cabin       | Cabin Number                                    |                                                                                    |
# | Embarked    | Port of Embarkation                             | C = Cherbourg, Q = Queenstown, S = Southampton                                     |                                       |
#
#
# - Are the numerical variables correlated?

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numerical_data = data.select_dtypes(include=['int64', 'float64'])
numerical_data.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_56919e01_5bee_11eb_86f1_803049142908row0_col0,#T_56919e01_5bee_11eb_86f1_803049142908row1_col1,#T_56919e01_5bee_11eb_86f1_803049142908row2_col2,#T_56919e01_5bee_11eb_86f1_803049142908row3_col3,#T_56919e01_5bee_11eb_86f1_803049142908row4_col4,#T_56919e01_5bee_11eb_86f1_803049142908row5_col5,#T_56919e01_5bee_11eb_86f1_803049142908row6_col6{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row0_col1{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row0_col2{
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row0_col3{
#             background-color:  #9dbdff;
#             color:  #000000;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row0_col4,#T_56919e01_5bee_11eb_86f1_803049142908row3_col1{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row0_col5{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row0_col6{
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row1_col0{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row1_col2{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row1_col3{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row1_col4{
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row1_col5{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row1_col6{
#             background-color:  #e2dad5;
#             color:  #000000;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row2_col0{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row2_col1,#T_56919e01_5bee_11eb_86f1_803049142908row2_col3,#T_56919e01_5bee_11eb_86f1_803049142908row2_col6,#T_56919e01_5bee_11eb_86f1_803049142908row3_col4,#T_56919e01_5bee_11eb_86f1_803049142908row3_col5,#T_56919e01_5bee_11eb_86f1_803049142908row4_col0,#T_56919e01_5bee_11eb_86f1_803049142908row6_col2{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row2_col4{
#             background-color:  #9ebeff;
#             color:  #000000;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row2_col5{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row3_col0{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row3_col2{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row3_col6{
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row4_col1{
#             background-color:  #84a7fc;
#             color:  #000000;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row4_col2{
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row4_col3{
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row4_col5{
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row4_col6{
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row5_col0{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row5_col1{
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row5_col2{
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row5_col3{
#             background-color:  #6384eb;
#             color:  #000000;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row5_col4{
#             background-color:  #ead5c9;
#             color:  #000000;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row5_col6{
#             background-color:  #dbdcde;
#             color:  #000000;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row6_col0{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row6_col1{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row6_col3{
#             background-color:  #abc8fd;
#             color:  #000000;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row6_col4{
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }#T_56919e01_5bee_11eb_86f1_803049142908row6_col5{
#             background-color:  #adc9fd;
#             color:  #000000;
#         }</style><table id="T_56919e01_5bee_11eb_86f1_803049142908" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >PassengerId</th>        <th class="col_heading level0 col1" >Survived</th>        <th class="col_heading level0 col2" >Pclass</th>        <th class="col_heading level0 col3" >Age</th>        <th class="col_heading level0 col4" >SibSp</th>        <th class="col_heading level0 col5" >Parch</th>        <th class="col_heading level0 col6" >Fare</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_56919e01_5bee_11eb_86f1_803049142908level0_row0" class="row_heading level0 row0" >PassengerId</th>
#                         <td id="T_56919e01_5bee_11eb_86f1_803049142908row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_56919e01_5bee_11eb_86f1_803049142908row0_col1" class="data row0 col1" >-0.005007</td>
#                         <td id="T_56919e01_5bee_11eb_86f1_803049142908row0_col2" class="data row0 col2" >-0.035144</td>
#                         <td id="T_56919e01_5bee_11eb_86f1_803049142908row0_col3" class="data row0 col3" >0.036847</td>
#                         <td id="T_56919e01_5bee_11eb_86f1_803049142908row0_col4" class="data row0 col4" >-0.057527</td>
#                         <td id="T_56919e01_5bee_11eb_86f1_803049142908row0_col5" class="data row0 col5" >-0.001652</td>
#                         <td id="T_56919e01_5bee_11eb_86f1_803049142908row0_col6" class="data row0 col6" >0.012658</td>
#             </tr>
#             <tr>
#                         <th id="T_56919e01_5bee_11eb_86f1_803049142908level0_row1" class="row_heading level0 row1" >Survived</th>
#                         <td id="T_56919e01_5bee_11eb_86f1_803049142908row1_col0" class="data row1 col0" >-0.005007</td>
#                         <td id="T_56919e01_5bee_11eb_86f1_803049142908row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_56919e01_5bee_11eb_86f1_803049142908row1_col2" class="data row1 col2" >-0.338481</td>
#                         <td id="T_56919e01_5bee_11eb_86f1_803049142908row1_col3" class="data row1 col3" >-0.077221</td>
#                         <td id="T_56919e01_5bee_11eb_86f1_803049142908row1_col4" class="data row1 col4" >-0.035322</td>
#                         <td id="T_56919e01_5bee_11eb_86f1_803049142908row1_col5" class="data row1 col5" >0.081629</td>
#                         <td id="T_56919e01_5bee_11eb_86f1_803049142908row1_col6" class="data row1 col6" >0.257307</td>
#             </tr>
#             <tr>
#                         <th id="T_56919e01_5bee_11eb_86f1_803049142908level0_row2" class="row_heading level0 row2" >Pclass</th>
#                         <td id="T_56919e01

# %% [markdown]
# Not really. The strongest correlations are with Pclass and Fare, which makes sense since upper class tickets will be more money. Age is also correlated with Pclass and SibSp since many families were travelling together and larger families tended to be poorer

# %% [markdown]
# - Are the distributions of numerical variables the same or different among survived and not survived? Is the survival rate different for different values? For example, were people more likely to survive if they were younger?

# %%
survived_df = data[data['Survived'] == 1]
died_df = data[data['Survived'] == 0]

plt.hist(survived_df['Age'], bins = np.arange(0,100,5), color = "green", histtype = "step")
plt.hist(died_df['Age'], bins = np.arange(0,100,5), color = "red", histtype = "step")
plt.title('Age: Survived vs Perished')
plt.xlabel("Age (in years)")
plt.ylabel("Count")
plt.show()

# %%
survived_df = data[data['Survived'] == 1]
died_df = data[data['Survived'] == 0]

plt.hist(survived_df['Fare'], bins = np.arange(0,100,5), color = "green", histtype = "step")
plt.hist(died_df['Fare'], bins = np.arange(0,100,5), color = "red", histtype = "step")
plt.title('Fare Cost: Survived vs Perished')
plt.xlabel("Fare (in dollars)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# It's hard to draw conclusions based on the graphs alone, but age or fare doesn't seem to be a large factor whether someone were to survive or not. Class on the other hand is a strong factor. If someone was in 3rd Class, they were much more likely to perish

# %% [markdown]
# - Are there different survival rates in different categories? For example, did more women survived than man?

# %%
sns.catplot(x="Sex", hue="Survived", col="Pclass",
                data=data, kind="count",
                height=4, aspect=.7);

# %% [markdown]
# We have a strong visual correlation between survivability vs sex as well as surivivability and class. Men were much more likely to perish compared to women and men in third class were very likely to perish

# %% [markdown]
# ### Step 5: Look at summary information about your data (total, mean, min, max, freq, unique, etc.)  Does this present any more questions for you?  Does it lead you to a conclusion yet?

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.describe(include=['O'])
# Out:
#                                 Name   Sex  Ticket Cabin Embarked
# count                            891   891     891   204      889
# unique                           891     2     681   147        3
# top     Berglund, Mr. Karl Ivar Sven  male  347082    G6        S
# freq                               1   577       7     4      644

# %% [markdown]
# No conclusions yet. We can see that most of our tickets were purchased for under \\$30, but we have a strange outlier at \\$512. We also have 3 unique embarking locations in our data.

# %% [markdown]
# ### Step 6: Make some histograms of your data (“A picture is worth a thousand words!”)
# -	Most of the passengers are around 20 to 30 years old and don't have siblings or relatives with them. A large amount of the tickets sold were less than \\$50. There are very few tickets sold where the fare was over \\$500.

# %%
import matplotlib.pyplot as plt

fig, ((ax1,ax2),(ax3, ax4)) = plt.subplots(2, 2, figsize=(16,10))
ax1.hist(data['Age'], bins = 25)
ax1.title.set_text('Histogram of Age')

ax2.hist(data['Fare'], bins = 50)
ax2.title.set_text('Histogram of Fare')

ax3.hist(data['SibSp'], bins = max(data['Parch']))
ax3.title.set_text('Histogram of SibSp')

ax4.hist(data['Parch'], bins = max(data['Parch']))
ax4.title.set_text('Histogram of Parch')

# %% [markdown]
# ### Step 7: Make some bar charts for variables with only a few options.
# - Ticket and Cabin have more than 100 variables so don’t do those!

# %%
import matplotlib.pyplot as plt

fig, ((ax1,ax2),(ax3, ax4)) = plt.subplots(2, 2, figsize=(16,10))

data['Survived'].value_counts().sort_index().plot(kind='bar', ax=ax1)
ax1.title.set_text('Count of Passengers by Survival')

data['Sex'].value_counts().sort_index().plot(kind='bar', ax=ax2)
ax2.title.set_text('Count of Passengers by Sex')

data['Pclass'].value_counts().sort_index().plot(kind='bar', ax=ax3)
ax3.title.set_text('Count of Passenger Class')

data['Embarked'].value_counts().sort_index().plot(kind='bar', ax=ax4)
ax4.title.set_text('Count of Embarking Locations')

# %% [markdown]
# ### Step 8: To see if the data is correlated, make some Pearson Ranking charts
# - Notice that in my sample code, I have saved this png file.
# - The correlation between the variables is low (1 or -1 is high positive or high negative, 0 is low or no correlation)  These results show there is “some” positive correlation but it’s not a high correlation.

# %%
# Mild cleaning to ensure we get sex and location in our plot
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

sex_dict = {"male":0,
            "female":1}

def locationator(ser):
    location_dict = {"C":1, 
                     "S":2, 
                     "Q":3}
    if pd.isna(ser):
        return np.nan
    else:
        return location_dict[ser]

selected_data = data.drop(['PassengerId', 'Name', 'Ticket' , 'Cabin'], axis = 1)

selected_data['Sex'] = selected_data['Sex'].apply(lambda x: sex_dict[x])
selected_data['Embarked'] = selected_data['Embarked'].apply(locationator)
selected_data

transformed = scaler.fit_transform(selected_data)
transformed_pd = pd.DataFrame(transformed)
transformed_pd.columns= selected_data.columns

transformed_pd
# Out:
#      Survived  Pclass  Sex       Age  SibSp     Parch      Fare  Embarked
# 0         0.0     1.0  0.0  0.271174  0.125  0.000000  0.014151       0.5
# 1         1.0     0.0  1.0  0.472229  0.125  0.000000  0.139136       0.0
# 2         1.0     1.0  1.0  0.321438  0.000  0.000000  0.015469       0.5
# 3         1.0     0.0  1.0  0.434531  0.125  0.000000  0.103644       0.5
# 4         0.0     1.0  0.0  0.434531  0.000  0.000000  0.015713       0.5
# ..        ...     ...  ...       ...    ...       ...       ...       ...
# 886       0.0     0.5  0.0  0.334004  0.000  0.000000  0.025374       0.5
# 887       1.0     0.0  1.0  0.233476  0.000  0.000000  0.058556       0.5
# 888       0.0     1.0  1.0       NaN  0.125  0.333333  0.045771       0.5
# 889       1.0     0.0  0.0  0.321438  0.000  0.000000  0.058556       0.0
# 890       0.0     1.0  0.0  0.396833  0.000  0.000000  0.015127       1.0
#
# [891 rows x 8 columns]

# %%
numerical_data = data.select_dtypes(include=['int64', 'float64'])
transformed_pd.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_5929e9d1_5bee_11eb_ae0f_803049142908row0_col0,#T_5929e9d1_5bee_11eb_ae0f_803049142908row1_col1,#T_5929e9d1_5bee_11eb_ae0f_803049142908row2_col2,#T_5929e9d1_5bee_11eb_ae0f_803049142908row3_col3,#T_5929e9d1_5bee_11eb_ae0f_803049142908row4_col4,#T_5929e9d1_5bee_11eb_ae0f_803049142908row5_col5,#T_5929e9d1_5bee_11eb_ae0f_803049142908row6_col6,#T_5929e9d1_5bee_11eb_ae0f_803049142908row7_col7{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row0_col1{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row0_col2{
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row0_col3{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row0_col4{
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row0_col5{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row0_col6{
#             background-color:  #e2dad5;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row0_col7{
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row1_col0,#T_5929e9d1_5bee_11eb_ae0f_803049142908row1_col2,#T_5929e9d1_5bee_11eb_ae0f_803049142908row1_col3,#T_5929e9d1_5bee_11eb_ae0f_803049142908row1_col6,#T_5929e9d1_5bee_11eb_ae0f_803049142908row3_col4,#T_5929e9d1_5bee_11eb_ae0f_803049142908row3_col5,#T_5929e9d1_5bee_11eb_ae0f_803049142908row6_col1,#T_5929e9d1_5bee_11eb_ae0f_803049142908row6_col7{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row1_col4{
#             background-color:  #9ebeff;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row1_col5{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row1_col7{
#             background-color:  #d1dae9;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row2_col0{
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row2_col1{
#             background-color:  #93b5fe;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row2_col3{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row2_col4{
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row2_col5,#T_5929e9d1_5bee_11eb_ae0f_803049142908row5_col1{
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row2_col6{
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row2_col7,#T_5929e9d1_5bee_11eb_ae0f_803049142908row3_col0{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row3_col1{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row3_col2{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row3_col6{
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row3_col7{
#             background-color:  #7396f5;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row4_col0{
#             background-color:  #84a7fc;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row4_col1{
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row4_col2{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row4_col3{
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row4_col5{
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row4_col6{
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row4_col7{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row5_col0{
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row5_col2{
#             background-color:  #aac7fd;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row5_col3,#T_5929e9d1_5bee_11eb_ae0f_803049142908row7_col5{
#             background-color:  #6384eb;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row5_col4,#T_5929e9d1_5bee_11eb_ae0f_803049142908row7_col1{
#             background-color:  #ead5c9;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row5_col6{
#             background-color:  #dbdcde;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row5_col7{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row6_col0{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row6_col2{
#             background-color:  #97b8ff;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row6_col3{
#             background-color:  #abc8fd;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row6_col4{
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row6_col5{
#             background-color:  #adc9fd;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row7_col0{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row7_col2{
#             background-color:  #5875e1;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row7_col3{
#             background-color:  #89acfd;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row7_col4{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }#T_5929e9d1_5bee_11eb_ae0f_803049142908row7_col6{
#             background-color:  #7597f6;
#             color:  #000000;
#         }</style><table id="T_5929e9d1_5bee_11eb_ae0f_803049142908" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Survived</th>        <th class="col_heading level0 col1" >Pclass</th>        <th class="col_heading level0 col2" >Sex</th>        <th class="col_heading level0 col3" >Age</th>        <th class="col_heading level0 col4" >SibSp</th>        <th class="col_heading level0 col5" >Parch</th>        <th class="col_heading level0 col6" >Fare</th>        <th class="col_heading level0 col7" >Embarked</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5929e9d1_5bee_11eb_ae0f_803049142908level0_row0" class="row_heading level0 row0" >Survived</th>
#                         <td id="T_5929e9d1_5bee_11eb_ae0f_803049142908row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_5929e9d1_5bee_11eb_ae0f_803049142908row0_col1" class="data row0 col1" >-0.338481</td>
#                         <td id="T_5929e9d1_5bee_11eb_ae0f_803049142908row0_col2" class="data row0 col2" >0.543351</td>
#                         <td id="T_5929e9d1_5bee_11eb_ae0f_803049142908row0_col3" class="data row0 col3" >-0.077221

# %%
# import the package for visulization of the correlation
from yellowbrick.features import Rank2D

num_features = ['Survived','Pclass','Age','Sex', 'SibSp', 'Parch', 'Fare','Embarked']
# extract the numpy arrays from the data frame
X = transformed_pd[num_features].values

# instantiate the visualizer with the Covariance ranking algorithm
visualizer = Rank2D(features=num_features, algorithm='pearson', colormap = "coolwarm")
visualizer.fit(X)                # Fit the data to the visualizer
visualizer.transform(X)             # Transform the data
visualizer.poof(outpath="pcoords1.png") # Draw/show/poof the data
plt.show()

# %% [markdown]
# ### Step 9: Use Parallel Coordinates visualization to compare the distributions of numerical variables between passengers that survived and those that did not survive.
# - That’s a cool chart, isn’t it?!  Passengers traveling with siblings on the boat have a higher death rate and passengers who paid a higher fare had a higher survival rate

# %%
plt.figure(figsize=(16,9))
pd.plotting.parallel_coordinates(numerical_data, 'Survived', color = ["red","green"]);

# %%
plt.figure(figsize=(16,9))
pd.plotting.parallel_coordinates(transformed_pd, 'Survived', color = ['red', 'green']);

# %%
# Adding some jitter to the data to make it easier to see trends. 

def rand_jitter(array):
    '''This is a function I made for 530 that adds jitter to make plots easier to visualize'''
    stdev = .05 * (max(array) - min(array))
    return array + (np.random.randn(len(array)) * stdev)

for i in transformed_pd.columns:
    if i != "Survived":
        transformed_pd[i] = rand_jitter(transformed_pd[i])

plt.figure(figsize=(16,9))
pd.plotting.parallel_coordinates(transformed_pd, 'Survived', color = ['red', 'green']);

# %% [markdown]
# ### Step 10: Use Stack Bar Charts to compare passengers who survived to passengers who didn’t survive based on the other variables.
#
# - More females survived than men.  3rd Class Tickets had a lower survival rate.
# - Embarkation from Southampton port had a lower survival rate.

# %%
# I can't for the life of me figure out how to stack these bars.
# Hope this is okay. I have stacked bar plots below these

sns.catplot(x="Sex", hue="Survived", col="Pclass",
                data=data, kind="count",
                height=4, aspect=.7, );

# %%
sns.catplot(x="Sex", hue="Survived", col="Embarked",
                data=data, kind="count",
                height=4, aspect=.7, );

# %%
sns.catplot(x="Pclass", hue="Survived", col="Embarked",
                data=data, kind="count",
                height=4, aspect=.7, );

# %%
sns.displot(data, x='Sex', hue='Survived', multiple='stack');

# %%
data['Pclass'] = data['Pclass'].apply(str)
sns.displot(data, x='Pclass', hue='Survived', multiple='stack');

# %%
sns.displot(data[data['Embarked'].notnull()], x='Embarked', hue='Survived', multiple='stack');
