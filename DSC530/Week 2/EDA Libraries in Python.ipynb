# %%
# from IPython.core.display import display, HTML
# display(HTML("<style>.container { width:75% !important; }</style>"))

# %% [markdown]
# Week 2
# <br>Hotaling, Michael
# <br>2020-09-10
#
# # EDA Libraries in Python
# ### Sweetviz

# %%
# pip install Sweetviz

# %%
import pandas as  pd
df = pd.read_csv('mtcars.csv')
df.head()
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
import sweetviz as sv

advert_report = sv.analyze(df)

advert_report.show_html("mtcars.html")
# Out:
# :FEATURES DONE:                    |█████████████████████| [100%]   00:04  -> (00:00 left)
# :PAIRWISE DONE:                    |█████████████████████| [100%]   00:00  -> (00:00 left)
# Creating Associations graph... DONE!
# Report mtcars.html was generated! NOTEBOOK/COLAB USERS: no browser will pop up, the report is saved in your notebook/colab files.

# %% [markdown]
# ### pandas_profiling

# %%
# pip install ipywidgets

# %%
# pip install pandas_profiling

# %%
from pandas_profiling import ProfileReport 

profile = ProfileReport(df, 
                        title='mtcars', 
                        html={'style':{'full_width':True}}) 
profile.to_widgets()

# %% [markdown]
# ### Seaborn

# %%
# pip install seaborn

# %%
import seaborn as sns
from matplotlib import pyplot

# %%
for i in range(0, len(df.columns), 5):
    sns.pairplot(data=df,
                x_vars=df.columns[i:i+5],
                )

# %%
corr = df.drop('mpg', axis=1).corr()

pyplot.figure(figsize=(20, 20))

sns.heatmap(corr, 
            vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 20}, square=True);

# %% [markdown]
# ### matplotlib

# %%
pip install matplotlib

# %%
from matplotlib import pyplot as plt

# %%
df.plot(kind = 'scatter', x = "mpg", y = "disp");

# %%
df.groupby('cyl')['disp'].nunique().plot(kind='bar')
plt.show()
